# %% [markdown]
# # Module 4 Practice
#
# ### Student will be able to
#
# ## 3-4.1 Script Environment & Command Line Arguments
# * Distinguish if a Python code is running as a script or being imported as a module
# * Recognize the basic structure of a Unix command line
# * Parse command line arguments:
#     * Use add_argument method to parse command line arguments
#     * Add positional arguments
#     * Add optional arguments
#     * Utilize the parameters of add_argument to control how it works
# * Employ the parsed command line argument in a practical application
#
# ## 3-4.2 Variable Scope
# * Define local variables
# * Read and modify the value of local variables
# * Identify the scope of a variable
# * Define global variables
# * Read the value of global variables from local scopes
# * Modify the value of global variables from local scopes
#
# ## 3-4.3 Documenting Functions (Docstring)
# * Write one-line docstrings
# * Write multi-line docstrings
# * Access docstrings
#
# ## 3-4.4 Documenting Functions (`pydoc`)
# * Use pydoc to generate textual documentation
# * Use pydoc to generate HTML textual documentation

# %% [markdown]
# ---
# <font size="6" color="#B24C00"  face="verdana"> <B>Task 1</B></font>
#
# ## Script environment ( `__name__` )

# %% [markdown]
# ## Change working directory to `command_line`
#
# Necessary so all generated files are saved in this directory, the cell will generate an error message if you are already in the `command_line` directory.

# %%
# %cd command_line
# Out:
# [Errno 2] No such file or directory: 'command_line'
# /Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4

# %% [markdown]
# ## Sentence counter

# %%
# %%writefile sentence_counter.py

# [x] The following program contains a few functions to count the number of: vowels, consonants, and digits in a sentence.
# Modify the program so it only run the test case when the program is executed directly. 
# In other words, when the program is imported as a module for another program, it shouldn't display the test cases.
def count_vowels(sentence):
    """Count the number of vowels in sentence."""
    vowels = 0
    for c in sentence:
        if c.lower() in "aeiouy":
            vowels = vowels + 1
    return vowels

def count_consonants(sentence):
    """Count the number of consonants in sentence."""
    consonants = 0
    for c in sentence:
        if c.isalpha():
            if c.lower() not in "aeiouy":
                consonants = consonants + 1
    return consonants

def count_digits(sentence):
    """Count the number of digits in sentence."""
    digits = 0
    for c in sentence:
        if c.isdigit():
            digits = digits + 1
    return digits

test_sentence = "Plan 2 is not working!"
print("Number of vowels = {:d}".format(count_vowels(test_sentence)))
print("Number of consonants = {:d}".format(count_consonants(test_sentence)))
print("Number of digits = {:d}".format(count_digits(test_sentence)))
# Out:
# Writing sentence_counter.py

# %% [markdown]
# ---
# <font size="6" color="#B24C00"  face="verdana"> <B>Task 2</B></font>
#
# ## Parsing command line arguments

# %% [markdown]
# ## Change working directory to `command_line`
#
# Necessary so all generated files are saved in this directory, the cell will generate an error message if you are already in the `command_line` directory.

# %%
# %cd command_line
# Out:
# [Errno 2] No such file or directory: 'command_line'
# /Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4

# %% [markdown]
# ## Character art
#
# The following program is saved as `stairs.py`. Once you complete the task, you can test it using the next `bash` code cell

# %%
# %%writefile stairs.py

# [x] The following program generates a staircase character art
# The `size` variable controls the number of steps
# The `base_shape` defines the characters used to generate the art
# Modify the program so the `size` is set as a positional command line argument, and base_shape as an optional 
# command line argument with a default value of `[]`

import argparse

def gen_stairs(steps, base_shape):
    for row in range(steps):
        for col in range(steps):
            if(col <= row):
                print(base_shape, end = "")
        print()

# Define an argument parser object
parser = argparse.ArgumentParser()

# Add positional arguments
parser.add_argument('size', action = 'store', type = int, help = 'Controls the numbers of steps')

# Add optional arguments
parser.add_argument('-b', '--base_shape', metavar = "shape", action = 'store', type = str, default = "[]", help = 'Defines the characters used to generate the art')

# Parse command-line arguments
args = parser.parse_args()

# Program
# Generate a staircase with steps using '[]` as default a base shape 
gen_stairs(args.size, args.base_shape)
# Out:
# Overwriting stairs.py

# %%
# %%bash
#
# python3 stairs.py 6 -b '^' -h
# Out:
# usage: stairs.py [-h] [-b shape] size
#
# positional arguments:
#   size                  Controls the numbers of steps
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -b shape, --base_shape shape
#                         Defines the characters used to generate the art

# %% [markdown]
# ## Days counter

# %%
# %%writefile day_counter.py

# [x] Write a program that reads a date from the command line as numbers (month  then day then year),
# if the date entered is in the past, a message saying "The date has passed" should be printed
# if the date is in the future the program should display the number of days remaining from today till that date,
# there should be an optional command line flag that displays the results in total number of seconds instead of days

import argparse
from datetime import datetime, timedelta

# help message should look like:
'''
usage: day_counter.py [-h] [-s] month day year

positional arguments:
  month                Month as a number (1, 12)
  day                  Day as a number (1, 31) depending on the month
  year                 Year as a 4 digits number (2018)

optional arguments:
  -h, --help           show this help message and exit
  -s, --total_seconds  Show the time difference in total number of seconds
'''

# Define an argument parser object
parser = argparse.ArgumentParser()

# Add positional arguments
parser.add_argument('month', action = 'store', type = int, help = 'Month as a number (1, 12)')
parser.add_argument('day', action = 'store', type = int, help = 'Day as a number (1, 31) depending on the month')
parser.add_argument('year', action = 'store', type = int, help = 'Year as a 4 digit number (2018)')

# Add optional arguments
parser.add_argument('-s', '--total_seconds', action = 'store_true', help = 'Show the time difference in total number of seconds')

# Parse command-line arguments
args = parser.parse_args()

# Program
t = datetime(month = args.month, day = args.day, year = args.year)
td = abs(t - datetime.today())

if t < datetime.today():
    print("The date has passed")   
else:
    print("There is",td.days,"days left until this date")

# If args.total_seconds is used, print the date with the complete format
if args.total_seconds:
        print("There is",int(td.total_seconds()),"seconds difference between this date and today")
# Out:
# Overwriting day_counter.py

# %%
# %%bash
#
# python3 day_counter.py 3 2 2018 -s
# Out:
# The date has passed
# There is 21393801 seconds difference between this date and today

# %% [markdown]
# ## Adder

# %%
# %%writefile adder.py

# [x] Write a program that reads an unspecified number of integers from the command line,
# then prints out the sum of all the numbers
# the program should also have an optional argument to show the product of the numbers (in addition to the sum)


# help message should look like:
'''
usage: adder.py [-h] [-p] [numbers [numbers ...]]

positional arguments:
  numbers        numbers to be added (or multiplied)

optional arguments:
  -h, --help     show this help message and exit
  -p, --product  show the product of the numbers (in addition to the displayed
                 sum)
'''
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('numbers', action = 'store', nargs = '*', type = int, help = 'numbers to be added (or multiplied)')
parser.add_argument('-p', '--product', action = 'count', help = 'show the product of the numbers (in addition to the displayed sum)')
args = parser.parse_args()
print(sum(args.numbers))
if args.product:
    a = 1
    for b in args.numbers:
        a *= b
    print(a)
# Out:
# Overwriting adder.py

# %%
# %%bash
#
# python3 adder.py 2 3 5 10 -p
# Out:
# 20
# 300

# %% [markdown]
# ---
# <font size="6" color="#B24C00"  face="verdana"> <B>Task 3</B></font>
#
# ## Local variables

# %% [markdown]
# ## Fix the errors

# %%
# The following program displays the double of a number
# Fix the error/s in the program so the correct answer is displayed

def double(num):
    answer = num * 2
    return answer

print(double(6))
# Out:
# 12

# %% [markdown]
# ## Length Converter

# %%
# [x] The program below converts a length from Centimeters to Inches, Feet, Yards, and Miles
# Complete the functions cent2inches, cent2feet, cent2yards, cent2miles so they all return the expected result


def cent2inches(length):
    """
    Convert length from Centimeters to Inches.
    
    1 Centimeter = 0.393701 Inches
    
    args:
        length: in Centimeter (float)
        
    results:
        result: equivalent length in Inches (float)
    """
    result = 0.393791 * length  
    return result

def cent2feet(length):
    """
    Convert length from Centimeters to Feet.
    
    1 Centimeter = 0.0328084 Feet
    
    args:
        length: in Centimeter (float)
        
    results:
        result: equivalent length in Feet (float)
    """
    result = 0.0328084 * length  
    return result

def cent2yards(length):
    """
    Convert length from Centimeters to Yards.
    
    1 Centimeter = 0.0109361 Yards
    
    args:
        length: in Centimeter (float)
        
    results:
        result: equivalent length in Yards (float)
    """
    result = 0.0109361 * length  
    return result

def cent2miles(length):
    """
    Convert length from Centimeters to Miles.
    
    1 Centimeter = 6.2137e-6 Miles
    
    args:
        length: in Centimeter (float)
        
    results:
        result: equivalent length in Miles (float)
    """
    result = 6.2137e-6 * length  
    return result

def main():
    length = float(input("Enter length in Centimeters: "))
    
    # In Inches
    inches = cent2inches(length)
    
    # In Feet
    feet = cent2feet(length)
    
    # In Yards
    yards = cent2yards(length)
    
    # In Miles
    miles = cent2miles(length)
    
    print('{:.2f} [cm] = {:.2f} [inches]", {:.2f} [feet], {:.2f} [yards], {:.2e} [miles]'.format(length, inches, feet, yards, miles))
    
if __name__ == '__main__':
    main()
# Out:
# Enter length in Centimeters: 120
# 120.00 [cm] = 47.25 [inches]", 3.94 [feet], 1.31 [yards], 7.46e-04 [miles]

# %%
# [x] The program below converts a length from Centimeters to Feet without using direct conversion
# Complete the functions cent2inches, inches2feet, and cent2feet so they return the expected result
# You should use cent2inches and inchest2feet in cent2feet

def cent2inches(length):
    """
    Convert length from Centimeters to Inches.
    
    1 Centimeter = 0.393701 Inches
    
    args:
        length: in Centimeter (float)
        
    results:
        result: equivalent length in Inches (float)
    """
    result = 0.393701 * length
    return result

def inches2feet(length):
    """
    Convert length from Inches to Feet.
    
    1 Inch = 0.0833333 Feet
    
    args:
        length: in Inches (float)
        
    results:
        result: equivalent length in Feet (float)
    """
    result = 0.0833333 * length
    return result

def cent2feet(length):
    """
    Convert length from Centimeters to Yards.
    
    The conversion rate is unknown, you have to use cent2inches and inches2feet
    
    args:
        length: in Centimeter (float)
        
    results:
        result: equivalent length in Yards (float)
    """
    result = inches2feet(cent2inches(length))
    return result

def main():
    length = float(input("Enter length in Centimeters: "))
    
    # In Feet
    feet = cent2feet(length)
    
    print('{:.2f} [cm] = {:.2f} [feet]'.format(length, feet))
    
if __name__ == '__main__':
    main()
# Out:
# Enter length in Centimeters: 120
# 120.00 [cm] = 3.94 [feet]

# %% [markdown]
# ---
# <font size="6" color="#B24C00"  face="verdana"> <B>Task 4</B></font>
#
# ## Global variables

# %% [markdown]
# ### Formatted Phone Number

# %%
# [x] Complete the function `formatted_phone()` so it displays the PHONE number as 777-248-3940

PHONE = "7895550153"

def formatted_phone():
    print("{:s}-{:s}-{:s}".format(PHONE[0:3],PHONE[3:6],PHONE[6:]))
    
formatted_phone()
# Out:
# 789-555-0153

# %% [markdown]
# ### Changing global variables

# %%
# [x] In the following program, the function change_x should change the value stored in x from 5 to 7
# modify the function so the value of x is changed from within the function

x = 5

def change_x():
    global x
    x = 7
    
print("Before change x =", x) # should be 5
change_x()
print("After change x =", x) # should be 7
# Out:
# Before change x = 5
# After change x = 7

# %%
# [x] The function upper_case should change the NAME to upper case
# correct the function so that NAME is changed permanently

# HINT: Use the string function str.upper()

NAME = "Skye Homsi"

def upper_case():
    global NAME
    NAME = NAME.upper()
    return NAME

print("Current name case:", NAME)
upper_case()
print("Updated name case:", NAME)
# Out:
# Current name case: Skye Homsi
# Updated name case: SKYE HOMSI

# %% [markdown]
# ---
# <font size="6" color="#B24C00"  face="verdana"> <B>Task 5</B></font>
#
# ## Docstrings

# %%
# [x] The function `average` computes the average of a list (or tuple) T
# Document the function using a one-line docstring
def average(T):
    '''computes the average of a list (or tuple)'''
    s = 0
    for num in T:
        s = s + num
    
    return s / len(T)
    
print(average.__doc__)
help(average)
# Out:
# computes the average of a list (or tuple)
# Help on function average in module __main__:
#
# average(T)
#     computes the average of a list (or tuple)

# %%
# [x] The following functions compute the area and circumference of a circle with radius r
# Document both function using a one-line docstring

from math import pi

def circle_area(r):
    '''computes the area of a circle with radius r'''
    return pi * r ** 2

def circle_circumference(r):
    '''computes the circumference of a circle with radius r'''
    return 2 * pi * r

print(circle_area.__doc__)
help(circle_area)
print(circle_circumference.__doc__)
help(circle_circumference)

# %%
# [x] As you saw before, the function gen_stairs generates a number of stairs using (base_shape)
# Document the function using a multi-line docstring

def gen_stairs(steps, base_shape):
    '''prints a number of stairs using a base shape
       
    args:
        steps: number of steps
        base_shape: shape with which steps are drawn
    
    returns:
        nothing
    '''
    for row in range(steps):
        for col in range(steps):
            if(col <= row):
                print(base_shape, end = "")
        print()

# Generate a staircase with 6 steps using '[]` as a base shape               
gen_stairs(6, '[]')

print(gen_stairs.__doc__)
help(gen_stairs)
# Out:
# []
# [][]
# [][][]
# [][][][]
# [][][][][]
# [][][][][][]
# prints a number of stairs using a base shape
#
#     args:
#         steps: number of steps
#         base_shape: shape with which steps are drawn
#
#     returns:
#         nothing
#
# Help on function gen_stairs in module __main__:
#
# gen_stairs(steps, base_shape)
#     prints a number of stairs using a base shape
#
#     args:
#         steps: number of steps
#         base_shape: shape with which steps are drawn
#
#     returns:
#         nothing

# %%
# [x] The following function returns the minimum and maximum of a tuple (or list) T
# # Document the function using a multi-line docstring

def min_max(T):
    '''
    finds the minimum and maximum within a list / tuple
    
    args:
        table / tuple
        
    returns:
        minimum and maximum within the list / tuple
    
    '''
    return (min(T), max(T))

print(min_max.__doc__)
help(min_max)
# Out:
#     finds the minimum and maximum within a list / tuple
#
#     args:
#         table / tuple
#
#     returns:
#         minimum and maximum within the list / tuple
#
#
# Help on function min_max in module __main__:
#
# min_max(T)
#     finds the minimum and maximum within a list / tuple
#
#     args:
#         table / tuple
#
#     returns:
#         minimum and maximum within the list / tuple

# %% [markdown]
# ---
# <font size="6" color="#B24C00"  face="verdana"> <B>Task 6</B></font>
#
# ## `pydoc`

# %% [markdown]
# The following program is a code from a previous module. Though the working code is not included, the documentation is thorough and complete. Use `pydoc` to generate the textual documentation page.
#
# NOTE: You do not need to complete the functions' code to generate the documentation pages

# %%
# %%writefile weather.py
# [x] In this project, you will read a CSV file containing about 25K lines of weather information 
# and store the information in a Python dictionary. You will then use the dictionary to find out
# the hottest, coldest, rainiest years and so on...
# You will see that the dictionary's search optimization algorithms will allow you to explore 
# this large dataset without any noticeable delays.
# The logic of the program is in the `main` function, read it before writing any code.
# Use the description and examples under each of the following functions to implement them:
# 1) convert_file(file_path)
# 2) add_rainy(weather)
# 3) consolidate(weather)
# 4) year_info(year, yearly_weather)
# 5) hottest(yearly_weather)
# 6) coldest(yearly_weather)
# 7) rainiest_days(yearly_weather)
# 8) highest_prcp(yearly_weather)
from datetime import date, datetime
import os
def convert_file(file_path):
    """
    Convert CSV file to a Python dictionary.
    
    The CSV file contains daily weather information arranged in rows,
    the rows contain  (date, precipitation (inches), maximum temperature (F), minimum temperature (F)) in order.
    First line in CSV file is a header (DATE, PRCP, TMAX, TMIN), the rest contain the weather data.   
    The function should read the data in the file and generate a dictionary where:
        1) keys are date objects (from the datetime module), using the daily date info in the file
        2) values are lists containing [TMAX, TMIN, PRCP] in order      
    args:
        file_path: path to the CSV file    
    returns:
        weather: the generated dictionary using date objects as keys and lists of weather info as values        
    examples:
    Input CSV file:
    DATE,PRCP,TMAX,TMIN
    12/10/2017,0,49,34
    12/11/2017,0,49,29
    12/12/2017,0,46,32
    12/13/2017,0,48,34
    12/14/2017,0,50,36
    12/15/2017,0.06,43,37
    12/16/2017,0.14,45,37
    12/17/2017,0.03,50,42
    12/18/2017,0.7,49,41
    12/19/2017,1,50,40
    12/20/2017,0.13,49,32
    12/21/2017,0.01,41,29
    12/22/2017,0.09,40,35
    12/23/2017,0,38,29
    12/24/2017,0.12,38,28
    Output dictionary (weather):
    {datetime.date(2017, 12, 10): [49, 34, 0.0],
     datetime.date(2017, 12, 11): [49, 29, 0.0],
     datetime.date(2017, 12, 12): [46, 32, 0.0],
     datetime.date(2017, 12, 13): [48, 34, 0.0],
     datetime.date(2017, 12, 14): [50, 36, 0.0],
     datetime.date(2017, 12, 15): [43, 37, 0.06],
     datetime.date(2017, 12, 16): [45, 37, 0.14],
     datetime.date(2017, 12, 17): [50, 42, 0.03],
     datetime.date(2017, 12, 18): [49, 41, 0.7],
     datetime.date(2017, 12, 19): [50, 40, 1.0],
     datetime.date(2017, 12, 20): [49, 32, 0.13],
     datetime.date(2017, 12, 21): [41, 29, 0.01],
     datetime.date(2017, 12, 22): [40, 35, 0.09],
     datetime.date(2017, 12, 23): [38, 29, 0.0],
     datetime.date(2017, 12, 24): [38, 28, 0.12]}
    """
    os.chdir("/Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 3/")
    if (file_path not in os.listdir("/Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 3/")):
        print("STOP!!!! Run the environment setup code!")
        return None
    else:
        weather = {}
        with open(file_path, 'r') as f:
            skip = f.readline()
            for a in range(0,25561):
                u = f.readline()
                u = u.rstrip()
                u = u.split(",")
                c = date_creater(u[0])
                if u[1] == "":
                    u[1] = 0
                if u[2] == "":
                    u[2] = 0
                if u[3] == "":
                    u[3] = 0
                weather[c] = [int(u[2]),int(u[3]),float(u[1])]
        return weather   
    #[x] open the file for reading (HINT: use `with` statement)
    #[x] ignore the first header line (DATE, PRCP, TMAX, TMIN)
    #[x] remove newline characters from end of each line (HINT: use str.rstrip())
    #[x] split line into a list (HINT: use str.split(','))
    #[x] create the date object from the first list element 
    # HINT: use the date_creater(date_string) function provided below
    #[x] read the weather related variables
    # precipitation
    # maximum temperature
    # minimum temperature   
    #[x] create dictionary key:value pair
def add_rainy(weather):
    """
    Emphasize rainy days using Boolean values.    
    Modify the weather dictionary by adding another Boolean element to the values' lists. 
    If precipitation is observed on a day (more than 0"), the associated list is appended by True.
    If precipitation is not observed (0"), the associated list is appended by False.   
    args:
        weather: dictionary, keys are date objects and values are lists [TMAX, TMIN, PRCP]        
    returns:
        None: the weather dictionary is modified directly, keys are date objects and values are lists [TMAX, TMIN, PRCP, RAINY_DAY]        
    examples:
    Input weather dictionary:
    {datetime.date(2017, 12, 10): [49, 34, 0.0],
     datetime.date(2017, 12, 11): [49, 29, 0.0],
     datetime.date(2017, 12, 12): [46, 32, 0.0],
     datetime.date(2017, 12, 13): [48, 34, 0.0],
     datetime.date(2017, 12, 14): [50, 36, 0.0],
     datetime.date(2017, 12, 15): [43, 37, 0.06],
     datetime.date(2017, 12, 16): [45, 37, 0.14],
     datetime.date(2017, 12, 17): [50, 42, 0.03],
     datetime.date(2017, 12, 18): [49, 41, 0.7],
     datetime.date(2017, 12, 19): [50, 40, 1.0],
     datetime.date(2017, 12, 20): [49, 32, 0.13],
     datetime.date(2017, 12, 21): [41, 29, 0.01],
     datetime.date(2017, 12, 22): [40, 35, 0.09],
     datetime.date(2017, 12, 23): [38, 29, 0.0],
     datetime.date(2017, 12, 24): [38, 28, 0.12]}    
    Updated weather dictionary with Boolean values
    {datetime.date(2017, 12, 10): [49, 34, 0.0, False],
     datetime.date(2017, 12, 11): [49, 29, 0.0, False],
     datetime.date(2017, 12, 12): [46, 32, 0.0, False],
     datetime.date(2017, 12, 13): [48, 34, 0.0, False],
     datetime.date(2017, 12, 14): [50, 36, 0.0, False],
     datetime.date(2017, 12, 15): [43, 37, 0.06, True],
     datetime.date(2017, 12, 16): [45, 37, 0.14, True],
     datetime.date(2017, 12, 17): [50, 42, 0.03, True],
     datetime.date(2017, 12, 18): [49, 41, 0.7, True],
     datetime.date(2017, 12, 19): [50, 40, 1.0, True],
     datetime.date(2017, 12, 20): [49, 32, 0.13, True],
     datetime.date(2017, 12, 21): [41, 29, 0.01, True],
     datetime.date(2017, 12, 22): [40, 35, 0.09, True],
     datetime.date(2017, 12, 23): [38, 29, 0.0, False],
     datetime.date(2017, 12, 24): [38, 28, 0.12, True]}
    """
    for a in weather.keys():
        if weather[a][2] > 0:
            weather[a].append(True)
        else:
            weather[a].append(False)
def consolidate(weather):
    """
    Consolidate the daily weather information by year.    
    Use the weather dictionary to generate a new consolidated dictionary (yearly_weather). 
    The new dictionary uses years as keys, and the associated values are lists containing (in order):
        1) The average of the highest recorded temperatures in the year (AVG_TMAX)
        2) The average of the lowest recorded temperatures in the year (AVG_TMIN)
        3) The total recorded precipitation in the year (TOTAL_PRCP)
        4) The total number of rainy days in the year (TOTAL_RAINY_DAYS)
        5) The number of recorded days (TOTAL_DAYS). 
           This element is necessary to account for days where the station breaks (missing recordings),
           or if the year hasn't finished yet.         
    args: 
        weather: dictionary, keys are date objects and values are lists [TMAX, TMIN, PRCP, RAINY_DAY]   
    returns:
        yearly_weather: consolidated dictionary, keys are years (int), values are lists 
                        [AVG_TMAX, AVG_TMIN, TOTAL_PRCP, TOTAL_RAINY_DAYS, TOTAL_DAYS]                       
    examples:
    Input weather dictionary:
    {datetime.date(2017, 12, 10): [49, 34, 0.0, False],
     datetime.date(2017, 12, 11): [49, 29, 0.0, False],
     datetime.date(2017, 12, 12): [46, 32, 0.0, False],
     datetime.date(2017, 12, 13): [48, 34, 0.0, False],
     datetime.date(2017, 12, 14): [50, 36, 0.0, False],
     datetime.date(2017, 12, 15): [43, 37, 0.06, True],
     datetime.date(2017, 12, 16): [45, 37, 0.14, True],
     datetime.date(2017, 12, 17): [50, 42, 0.03, True],
     datetime.date(2017, 12, 18): [49, 41, 0.7, True],
     datetime.date(2017, 12, 19): [50, 40, 1.0, True],
     datetime.date(2017, 12, 20): [49, 32, 0.13, True],
     datetime.date(2017, 12, 21): [41, 29, 0.01, True],
     datetime.date(2017, 12, 22): [40, 35, 0.09, True],
     datetime.date(2017, 12, 23): [38, 29, 0.0, False],
     datetime.date(2017, 12, 24): [38, 28, 0.12, True]}     
     Output yearly_weather dictionary:
     {2017: [45.666666666666664, 34.333333333333336, 2.28, 9, 15]}
    """    
    yearly_weather = {}
    for a in range(1948,2018):
        total_days = 0
        rainy_days = 0
        total_prec = 0
        total_max = 0
        total_min = 0
        for b in weather.keys():
            if b.year == a:
                total_days += 1
                total_prec += weather[b][2]
                total_max += weather[b][0]
                total_min += weather[b][1]
                if weather[b][3] == True:
                    rainy_days += 1
        yearly_weather.update({a:[total_max/total_days, total_min/total_days, total_prec, rainy_days, total_days]})
    return yearly_weather
def year_info(year, yearly_weather):
    """
    Convert the year's weather information to a formatted string.   
    Look for the weather information of `year` in the `yearly_weather` dictionary.
    If it exists, convert the information list into a formatted string:
            YEAR | AVG_TMAX | AVG_TMIN | TOTAL_PRCP | TOTAL_RAINY_DAYS | TOTAL_DAYS
    If it does not exist, the formatted string should be:
            N/A  |    N/A   |    N/A   |     N/A    |        N/A       |    N/A       
    args:
        year: int value to look for in the yearly_weather dictionary       
        yearly_weather: consolidated dictionary, keys are years (int), values are lists 
                        [AVG_TMAX, AVG_TMIN, TOTAL_PRCP, TOTAL_RAINY_DAYS, TOTAL_DAYS]    
    returns:
        formatted_string: containing the year's weather information                        
    examples:
    Input yearly weather dictionary:
    {2017: [45.666666666666664, 34.333333333333336, 2.28, 9, 15]}  
    Output formatted string:
    == year_info(2017, yearly_weather) == (contained in the dictionary)
    ' 2017 |         45.67 |        34.33 |   2.28" |            9 |             15 '
    
    == year_info(2055, yearly_weather) == (not contained in the dictionary)
    ' N/A  |      N/A      |     N/A      |   N/A   |     N/A      |      N/A       '
    """
    if year in yearly_weather.keys():
        return "{:>10s} | {:s} | {:s} | {:s} | {:s} | {:s}".format("YEAR","AVG_TMAX","AVG_TMIN","TOTAL_PRCP","TOTAL_RAINY_DAYS","TOTAL_DAYS")+"\n"+"{:>10d} | {:^8.5f} | {:^8.5f} | {:^10.2f} | {:^16d} | {:^10d}".format(year,yearly_weather[year][0],yearly_weather[year][1],yearly_weather[year][2],yearly_weather[year][3],yearly_weather[year][4])+"\n"          
    if year not in yearly_weather.keys():
        return "{:>10s} | {:s} | {:s} | {:s} | {:s} | {:s}".format("YEAR","AVG_TMAX","AVG_TMIN","TOTAL_PRCP","TOTAL_RAINY_DAYS","TOTAL_DAYS")+"\n"+"{:>10s} | {:^8s} | {:^8s} | {:^10s} | {:^16s} | {:^10s}".format("N/A","N/A","N/A","N/A","N/A","N/A")+"\n"
def hottest(yearly_weather):
    """
    Find the hottest year in yearly_weather.    
    Look through all the years in the yearly_weather dictionary and return the year with 
    the highest average maximum temperature (highest AVG_TMAX)
    
    args:
        yearly_weather: consolidated dictionary, keys are years (int), values are lists 
                        [AVG_TMAX, AVG_TMIN, TOTAL_PRCP, TOTAL_RAINY_DAYS, TOTAL_DAYS]     
    returns:
        hottest_year: the year with the highest maximum temperature average (AVG_TMAX)
    """
    return(max(yearly_weather))       
def coldest(yearly_weather):
    """
    Find the coldest year in yearly_weather.   
    Look through all the years in the yearly_weather dictionary and return the year with 
    the lowest average minimum temperature (lowest AVG_TMIN)
    
    args:
        yearly_weather: consolidated dictionary, keys are years (int), values are lists 
                        [AVG_TMAX, AVG_TMIN, TOTAL_PRCP, TOTAL_RAINY_DAYS, TOTAL_DAYS] 
    
    returns:
        coldest_year: the year with the lowest minimum temperature average (AVG_TMIN)
    """
    return(min(yearly_weather))
def rainiest_days(yearly_weather):
    """
    Find the year with the largest number of rainy days in yearly_weather.
    
    Look through all the years in the yearly_weather dictionary and return the year with 
    the largest TOTAL_RAINY_DAYS    
    args:
        yearly_weather: consolidated dictionary, keys are years (int), values are lists 
                        [AVG_TMAX, AVG_TMIN, TOTAL_PRCP, TOTAL_RAINY_DAYS, TOTAL_DAYS]     
    returns:
        rainiest_year: the year with the largest number of rainy days
    """
    total_rainy_max = 0
    for a in yearly_weather.keys():
        if yearly_weather[a][3] >= total_rainy_max:
            total_rainy_max = yearly_weather[a][3]
            year = a
    return(year)
def highest_prcp(yearly_weather):
    """
    Find the year with the highest total precipitation in yearly_weather.
    
    Look through all the years in the yearly_weather dictionary and return the year with 
    the largest TOTAL_PRCP
    
    args:
        yearly_weather: consolidated dictionary, keys are years (int), values are lists 
                        [AVG_TMAX, AVG_TMIN, TOTAL_PRCP, TOTAL_RAINY_DAYS, TOTAL_DAYS] 
    
    returns:
        rainiest_year: the year with the highest total precipitation
    """
    total_prec_max = 0
    for a in yearly_weather.keys():
        if yearly_weather[a][2] >= total_prec_max:
            total_prec_max = yearly_weather[a][2]
            year = a
    return(year)
def date_creater(date_string):
    """Convert the date_string (formatted as m/d/yyyy) to a date object."""
    date_string = date_string.split("/")
    if len(date_string[0]) == 1:
        a = "0"+date_string[0]
        date_string[0] = a
    if len(date_string[1]) == 1:
        b = "0"+date_string[1]
        date_string[1] = b
    if int(date_string[2]) >= 48 and int(date_string[2]) <= 99:
        c = "19"+date_string[2]
    if int(date_string[2]) >0 and int(date_string[2]) < 18:
        c = "20"+date_string[2]
    if date_string[2] == "00":
        c = "2000"
    date_string[2] = c
    date_string = "/".join(date_string)
    d = datetime.strptime(date_string, "%m/%d/%Y")
    return d.date()
def dashes(count):
    """Print a fancy line of `count` dashes"""
    print("o" + count *'-' + "o")
def page_header(title):
    """Print a page header with a title surrounded by dashes"""
    dashes(78)
    print("|{:^78s}|".format(title))
    dashes(78)
def table_header():
    """Print the first row in a table  (header row)"""
    print()
    print(' {0:^4s} | {1:^13s} | {2:^12s} | {3:^7s} | {4:^12s} | {5:^14s} '.format("Year", "Avg High Temp", "Avg Low Temp", "Precip", "# Rainy days", "# Recorded days"))
    dashes(78)    
def display(title, years, yearly_weather):
    """Print a page with a header, title, and the weather information of all years as found in yearly_weather"""
    page_header(title)
    table_header()   
    # if years contain a single int, convert to a single item list
    if type(years) is not list: years = [years]    
    # print weather information for all years
    for year in years:
        print(year_info(year, yearly_weather))         
    # display this page till you go back to the main menu
    while True:
        m = input("Return to main menu [y/n]?")
        if m in 'yesYesYES':
            break     
def main():
    # convert the data in the (csv) file into a Python dictionary
    weather = convert_file("seattle_weather.csv")   
    # highlight rainy days by adding a Boolean entry to the dictionary's values
    add_rainy(weather)   
    # consolidate the weather data by year then store the result in a new dictionary
    yearly_weather = consolidate(weather)
    # earliest and latest years on record
    min_year = min(yearly_weather)
    max_year = max(yearly_weather)
    # menus functionality
    while True:
        # display header
        page_header("Weather Records")
        # display main menu
        print()
        print("Main Menu (choose an option to display):\n")
        print("1. Summary of a certain year")
        print("2. All years summary table")
        print("3. Hottest year on record")
        print("4. Coldest year on record")
        print("5. Year with most rainy days")
        print("6. Year with the highest precipitation")
        print("7. Quit")
        print()
        # display footer with user input message
        dashes(78)
        while True:
            try:
                option = input("Select an option (1, 7): ")
                option = int(option)
                if 1 <= option <= 7:
                    break # break the user input loop only, main loop does NOT break
            except ValueError:
                print("Cannot convert {:} to int".format(type(option)))       
        # execute relevant function
        # 1. Summary of a certain year
        if option == 1:
            # ask the user for a valid year
            while True:
                try:
                    year = input("Enter a year ({} - {})".format(min_year, max_year))
                    year = int(year)
                    if min_year <= year <= max_year:
                        break
                except ValueError:
                    print("Cannot convert {:} to int".format(type(option)))
            display("Year Summary", year, yearly_weather)
        # 2. All years summary table 
        elif option == 2:
            years = list(sorted(yearly_weather))
            display("Tabular Summary", years, yearly_weather)      
        # 3. Hottest year on record
        elif option == 3:
            year = hottest(yearly_weather)
            display("Hottest year on record", year, yearly_weather)            
        # 4. Coldest year on record   
        elif option == 4:
            year = coldest(yearly_weather)
            display("Coldest year on record", year, yearly_weather)           
        # 5. Year with most rainy days    
        elif option == 5:
            year = rainiest_days(yearly_weather)
            display("Year with most rainy days", year, yearly_weather)      
        # 6. Year with the highest precipitation
        elif option == 6:
            year = highest_prcp(yearly_weather)
            display("Year with the highest precipitation", year, yearly_weather)          
        # 7. Quit    
        elif option == 7:
            break
# Run the program  
main()
# Out:
# Overwriting weather.py

# %%
# %%bash
#
# pydoc weather
# Out:
# o------------------------------------------------------------------------------o
# |                               Weather Records                                |
# o------------------------------------------------------------------------------o
# ()
# Main Menu (choose an option to display):
#
# 1. Summary of a certain year
# 2. All years summary table
# 3. Hottest year on record
# 4. Coldest year on record
# 5. Year with most rainy days
# 6. Year with the highest precipitation
# 7. Quit
# ()
# o------------------------------------------------------------------------------o
# Select an option (1, 7): problem in weather - <type 'exceptions.EOFError'>: EOF when reading a line

# %% [markdown]
# ---
# <font size="6" color="#B24C00"  face="verdana"> <B>Module 4 Project</B></font>
#
# ## Caesar Cipher
#
# In this project, you will implement a program to encrypt and decrypt text using Caesar Cipher. The cipher is one of the oldest and simplest known encryption techniques known. It simply relies on substituting each character in a string by another character which is shifted by a certain number of places. For example, with a shift of 1 'a' becomes 'b', 'e' becomes 'f', and 'z' becomes 'a'. In the Caesar cipher, all characters are shifted by the same number of places and we refer to the shift value as key.
#
# To decrypt a message, you simply use the same key, which was used during the encryption procedure, to shift the characters back the same number of places. For example, with a key = 1 'b' becomes 'a', 'f' becomes 'e', and 'a' becomes 'z'.
#
# Since there are 26 letters in English, there are only 25 keys available for Caesar cipher. Therefore, it is easy to decipher a message without knowing the key. Simply use all possible keys to decrypt a message then read the outputs till one of them makes sense. This process is also implemented in the project.

# %% [markdown]
# ## Environment Setup
#
# The following code blocks move the working directory to `command_line` and generate the necessary text file:
# * `plain_message.txt` : contains a plain message that will be encrypted
# * `encrypted_message.txt`: contains an encrypted message where the key is unknown

# %% [markdown]
# ### Change working directory to `command_line`
#
# Necessary so all generated files are saved in this directory, the cell will generate an error message if you are already in the `command_line` directory.

# %%
# %cd "/Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4/command_line"
# Out:
# [Errno 2] No such file or directory: '/Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4/command_line'
# /Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4

# %% [markdown]
# ### Writing text files

# %%
# %%writefile plain_message.txt
#
# Software is a great combination between artistry and engineering.
#
# --Bill Gates
# Out:
# Writing plain_message.txt

# %%
# %%writefile encrypted_message.txt
#
# MHI LXVKXM!
#
# Mabl fxlltzx ptl xgvkrimxw nlbgz dxr = gbgxmxxg.
#
# tuvwxyzabcdefghijklmnopqrs
#
# TUVWXYZABCDEFGHIJKLMNOPQRS
# Out:
# Writing encrypted_message.txt

# %% [markdown]
# ## Program
#
# To finish this project, run the environment setup code, read the `main` function, then use the description and examples under each of the following functions to implement them:
# * `parse_command_line()`
# * `read_file(file_path)`
# * `write_file(message, file_path)`
# * `transform(message, key, decrypt)`
#
# Once you are done, use the terminal command line to:
# * Display the program's help message
# * Encrypt the text file `plain_message.txt` by key = 23 and save the result in `cipher_message.txt`
# * Find the key used to decrypt `encrypted_message.txt`

# %%
# %%writefile cipher.py
import argparse
import os

def parse_command_line():
    """
    Parse the command line arguments and return the parse_args object.
    
    There should be 1 positional argument and 6 optional arguments.
    The help message generated by the parser should look like:
    
    usage: cipher.py [-h] [-o outfile_path] [-k KEY] [-d] [-a] [-v] infile

    positional arguments:
      infile                input file to be encrypted or decrypted

    optional arguments:
      -h, --help            show this help message and exit
      -o outfile_path, --outfile outfile_path
                            output file
      -k KEY, --key KEY     encryption/decryption key (must be positive) (default
                            = 1)
      -d, --decrypt         decrypt the input file
      -a, --all             decrypt using all keys [1, 25], save outputs in
                            different files. (useful in case the key is lost or
                            unknown)
      -v, --verbose         verbose mode


    args:
        None
        
    returns:
        args: generated argparse object with all the passed command line arguments      
    """
    parser = argparse.ArgumentParser()
    
    # Add positional arguments
    parser.add_argument('infile', action = 'store', type = str, help = 'input file to be encrypted or decrypted')

    # Add optional arguments
    parser.add_argument('-o', '--outfile', metavar = 'outfile_path', action = 'store', type = str, help = 'output file')
    parser.add_argument('-k', '--key', metavar = 'KEY', action = 'store', default = 1, help = 'encryption/decryption key (must be positive) (default = 1)')
    parser.add_argument('-d', '--decrypt', action = 'store_true', help = 'decrypt the input file')
    parser.add_argument('-a', '--all', action = 'store_true', help = 'decrypt using all keys [1, 25], save outputs in different files. (useful in case the key is lost or unknown)')
    parser.add_argument('-v', '--verbose', action = 'store_true', help = 'verbose mode')

    args = parser.parse_args()
    #HINTS: Review Jupyter Notebook 3-4.1
    return(args)

def read_file(file_path):
    """
    Read file_path and return the content as string.
    
    The file must be opened and closed and the function should handle exceptions when they are raised.
    
    args:
        file_path: path to file
        
    returns:
        message: content of file in file_path as a string
    """
    os.chdir("/Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4/")
    if (file_path not in os.listdir("/Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4/")):
        print("STOP!!!! Run the environment setup code!")
        return None
    else:
        with open(file_path,'r') as f:
            try:
                t = f.read()
            except FileOpenError as exception:
                print(exception)
            else:
                return t
            
def write_file(message, file_path):
    """
    Write the message in file_path.
    
    The file must be opened and closed and the function should handle exceptions when they are raised.
    
    args:
        message: string to write in file
        file_path: path to file
        
    returns:
        None
    """
    os.chdir("/Users/julien.matuszak/Repos/python/Python Scripting Academy/Python Scripting Academy Unit 3/Module 4/")
    with open(file_path,'w') as f:
        try:
            f.write(message)
        except FileOpenError as exception:
            print(exception)
        else:
            return None

def transform(message, key, decrypt):
    """
    Encrypt or decrypt a message using Caesar cipher.
    
    Encryption and decryption is determined by the Boolean value in decrypt. Key determines the number of 
    places a character is shifted. When encrypting, use the positive value of key to shift the characters forward; 
    when decrypting, use the negative key to shift the characters backward. 
    
    The function should maintain characters that are not letters without change; for example, spaces, punctuations, 
    and numbers should not be encrypted or decrypted. Additionally, the case of the letters should be preserved, 
    small letters are transformed to other small letters and capital letters are transformed to capital letters.
    
    Use the function `shift` (provided later) to shift each character in message by the number in key.
    
    args:
        message: string to be encrypted or decrypted
        key: number of places to shift the characters (always positive)
        decrypt: Boolean; when False the message is encrypted,  when True the message is decrypted
        
    returns:
        transformed_message: encrypted (or decrypted) message
        
    examples:
        Encryption
        ==  transform("deal", 1, False) returns:
            "efbm"
        
        ==  transform("deal", 2, False) returns:
            "fgcn"
        
        ==  transform("deal", 30, False) is equivalent to transform(message, 4, False)
            "hiep"
        
        Decryption
        ==  transform("efbm", 1, True) returns:
            "deal"
            
        ==  transform("fgcn", 2, True) returns:
            "deal"
            
        ==  transform("hiep", 30, True) returns:
            "deal"    
        
    """
    if decrypt:
        split_message = message.split(" ")   
        decrypted = ""
        for a in split_message:
            for b in a:
                if b == "\n":
                    decrypted += "\n"
                elif b == ".":
                    decrypted += "."
                elif b == "!":
                    decrypted += "!"
                elif b == "-":
                    decrypted += "-"
                elif b == "=":
                    decrypted += "="
                else:
                    c = shift(b,key)
                    decrypted += c
            decrypted += " "
        return decrypted
    else:
        split_message = message.split(" ")
        crypted = ""
        for a in split_message:
            for b in a:
                if b == "\n":
                    crypted += "\n"
                elif b == ".":
                    crypted += "."
                elif b == "-":
                    crypted += "-"
                else:
                    c = shift(b,key)
                    crypted += c
            crypted += " "
        return crypted
 
def shift(char, key):    
    """
    Shift char by the value in key while maintaining the case (small/capital).
    
    If char contains non-letters (i.e. digits, punctuations, and white spaces), it is ignored.
    
    args:
        char: character to shift
        key: number of places to shift char
        
    returns:
        shifted character
        
    examples:
        shift('a', 1) ==> 'b'
        shift('z', -1) ==> 'y'
        shift('A', 5) ==> 'F'
        shift('H', 7) ==> 'O'
        shift('o', -10) ==> 'e'
        shift('a', 30) ==> 'e'
    """
    
    # ordered lower case alphabet
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    
    # will contain shifted lower case alphabet
    shifted_alphabet = ''
    for i in range(len(alphabet)):
        shifted_alphabet = shifted_alphabet + alphabet[(i + int(key)) % 26]
 
    if char.isalpha():
        char_index = alphabet.index(char.lower())
        shifted_char = shifted_alphabet[char_index]
    
        # keep char's case (upper or lower)
        if char.isupper():
            return shifted_char.upper()
        else:
            return shifted_char

def main():
    # parse command line arguments
    args = parse_command_line()
    # read content of infile to a string
    instring = read_file(args.infile)
    
    # verbose
    if args.verbose:
        print("Input file:")
        print("------------")
        print(instring)
        print()   
    # key is specified
    if not args.all:
        # encrypt/decrypt content of infile
        outstring = transform(instring, args.key, args.decrypt)

        # verbose
        if args.verbose:
            print("Output file:")
            print("------------")
            print(outstring)

        # write content of outstring to outfile
        write_file(outstring, args.outfile)
    # key is not specified, try all keys from 1 to 25 to decrypt infile
    else:
        for k in range(1, 26):
            # decrypt content of infile
            outstring = transform(instring, k, True)

            # verbose
            if args.verbose:
                print("Key =", k)
                print("------------")
                print(outstring)
                print()

            # write content of outstring to outfile
            write_file(outstring, "decrypted_by_" + str(k) + ".txt")
   
if __name__ == '__main__':
    main()
# Out:
# Overwriting cipher.py

# %% [markdown]
# ## Terminal commands
# * Display the program's help message
# * Encrypt the text file `plain_message.txt` by key = 23 and save the result in `cipher_message.txt`
# * Find the key used to decrypt `encrypted_message.txt`

# %% [markdown]
# ## Terminal commands

# %% [markdown]
# ### Help message

# %%
# %%bash
#
# python3 cipher.py -h
# Out:
# usage: cipher.py [-h] [-o outfile_path] [-k KEY] [-d] [-a] [-v] infile
#
# positional arguments:
#   infile                input file to be encrypted or decrypted
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -o outfile_path, --outfile outfile_path
#                         output file
#   -k KEY, --key KEY     encryption/decryption key (must be positive) (default
#                         = 1)
#   -d, --decrypt         decrypt the input file
#   -a, --all             decrypt using all keys [1, 25], save outputs in
#                         different files. (useful in case the key is lost or
#                         unknown)
#   -v, --verbose         verbose mode

# %% [markdown]
# ### Encrypt `plain_message.txt` by key = 23

# %%
# %%bash
#
# python3 cipher.py plain_message.txt -k 23 -v -o cipher_message.txt
# Out:
# Input file:
# ------------
#
# Software is a great combination between artistry and engineering.
#
# --Bill Gates
#
# Output file:
# ------------
#
# Plcqtxob fp x dobxq zljyfkxqflk ybqtbbk xoqfpqov xka bkdfkbbofkd.
#
# --Yfii Dxqbp

# %% [markdown]
# ### Finding the key to decrypt `encrypted_message.txt`

# %%
# %%bash
#
# python3 cipher.py encrypted_message.txt -a -v
# Out:
# Input file:
# ------------
#
# MHI LXVKXM!
#
# Mabl fxlltzx ptl xgvkrimxw nlbgz dxr = gbgxmxxg.
#
# tuvwxyzabcdefghijklmnopqrs
#
# TUVWXYZABCDEFGHIJKLMNOPQRS
#
#
#
#
# N
#
# NI
#
# NIJ
#
# NIJ M
#
# NIJ MY
#
# NIJ MYW
#
# NIJ MYWL
#
# NIJ MYWLY
#
# NIJ MYWLYN
#
# NIJ MYWLYN!
#
# NIJ MYWLYN!
#
#
# NIJ MYWLYN!
#
#
#
# NIJ MYWLYN!
#
# N
#
# NIJ MYWLYN!
#
# Nb
#
# NIJ MYWLYN!
#
# Nbc
#
# NIJ MYWLYN!
#
# Nbcm
#
# NIJ MYWLYN!
#
# Nbcm g
#
# NIJ MYWLYN!
#
# Nbcm gy
#
# NIJ MYWLYN!
#
# Nbcm gym
#
# NIJ MYWLYN!
#
# Nbcm gymm
#
# NIJ MYWLYN!
#
# Nbcm gymmu
#
# NIJ MYWLYN!
#
# Nbcm gymmua
#
# NIJ MYWLYN!
#
# Nbcm gymmuay
#
# NIJ MYWLYN!
#
# Nbcm gymmuay q
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qu
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum y
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yh
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhw
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwl
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwls
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsj
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjn
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjny
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx o
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx om
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omc
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omch
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha e
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha ey
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys =
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = h
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hc
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hch
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchy
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchyn
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchyny
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyy
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
#
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# u
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uv
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvw
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwx
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxy
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyz
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyza
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzab
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabc
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcd
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcde
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdef
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefg
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefgh
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghi
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghij
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijk
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijkl
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklm
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmn
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmno
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnop
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopq
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqr
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrs
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
#
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# U
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UV
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVW
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWX
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXY
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZ
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZA
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZAB
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABC
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCD
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDE
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEF
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFG
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGH
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHI
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJ
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJK
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKL
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLM
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMN
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMNO
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMNOP
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMNOPQ
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMNOPQR
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMNOPQRS
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMNOPQRST
# Key = 1
# ------------
#
# NIJ MYWLYN!
#
# Nbcm gymmuay qum yhwlsjnyx omcha eys = hchynyyh.
#
# uvwxyzabcdefghijklmnopqrst
#
# UVWXYZABCDEFGHIJKLMNOPQRST
#
#
#
#
# O
#
# OJ
#
# OJK
#
# OJK N
#
# OJK NZ
#
# OJK NZX
#
# OJK NZXM
#
# OJK NZXMZ
#
# OJK NZXMZO
#
# OJK NZXMZO!
#
# OJK NZXMZO!
#
#
# OJK NZXMZO!
#
#
#
# OJK NZXMZO!
#
# O
#
# OJK NZXMZO!
#
# Oc
#
# OJK NZXMZO!
#
# Ocd
#
# OJK NZXMZO!
#
# Ocdn
#
# OJK NZXMZO!
#
# Ocdn h
#
# OJK NZXMZO!
#
# Ocdn hz
#
# OJK NZXMZO!
#
# Ocdn hzn
#
# OJK NZXMZO!
#
# Ocdn hznn
#
# OJK NZXMZO!
#
# Ocdn hznnv
#
# OJK NZXMZO!
#
# Ocdn hznnvb
#
# OJK NZXMZO!
#
# Ocdn hznnvbz
#
# OJK NZXMZO!
#
# Ocdn hznnvbz r
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rv
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn z
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zi
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zix
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixm
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmt
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtk
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtko
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkoz
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy p
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pn
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pnd
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndi
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib f
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fz
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt =
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = i
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = id
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idi
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idiz
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizo
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizoz
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozz
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
#
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# v
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vw
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwx
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxy
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyz
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyza
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzab
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabc
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcd
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcde
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdef
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefg
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefgh
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghi
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghij
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijk
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijkl
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklm
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmn
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmno
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnop
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopq
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqr
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrs
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrst
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
#
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# V
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VW
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWX
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXY
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZ
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZA
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZAB
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABC
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCD
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDE
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEF
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFG
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGH
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHI
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJ
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJK
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKL
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLM
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMN
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNO
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNOP
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNOPQ
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNOPQR
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNOPQRS
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNOPQRST
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNOPQRSTU
# Key = 2
# ------------
#
# OJK NZXMZO!
#
# Ocdn hznnvbz rvn zixmtkozy pndib fzt = idizozzi.
#
# vwxyzabcdefghijklmnopqrstu
#
# VWXYZABCDEFGHIJKLMNOPQRSTU
#
#
#
#
# P
#
# PK
#
# PKL
#
# PKL O
#
# PKL OA
#
# PKL OAY
#
# PKL OAYN
#
# PKL OAYNA
#
# PKL OAYNAP
#
# PKL OAYNAP!
#
# PKL OAYNAP!
#
#
# PKL OAYNAP!
#
#
#
# PKL OAYNAP!
#
# P
#
# PKL OAYNAP!
#
# Pd
#
# PKL OAYNAP!
#
# Pde
#
# PKL OAYNAP!
#
# Pdeo
#
# PKL OAYNAP!
#
# Pdeo i
#
# PKL OAYNAP!
#
# Pdeo ia
#
# PKL OAYNAP!
#
# Pdeo iao
#
# PKL OAYNAP!
#
# Pdeo iaoo
#
# PKL OAYNAP!
#
# Pdeo iaoow
#
# PKL OAYNAP!
#
# Pdeo iaoowc
#
# PKL OAYNAP!
#
# Pdeo iaoowca
#
# PKL OAYNAP!
#
# Pdeo iaoowca s
#
# PKL OAYNAP!
#
# Pdeo iaoowca sw
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo a
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo aj
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajy
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajyn
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynu
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynul
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulp
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpa
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz q
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qo
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoe
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoej
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc g
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc ga
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau =
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = j
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = je
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jej
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jeja
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejap
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapa
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaa
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
#
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# w
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wx
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxy
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyz
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyza
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzab
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabc
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcd
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcde
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdef
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefg
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefgh
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghi
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghij
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijk
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijkl
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklm
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmn
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmno
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnop
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopq
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqr
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrs
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrst
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstu
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
#
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# W
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WX
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXY
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZ
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZA
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZAB
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABC
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCD
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDE
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEF
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFG
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGH
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHI
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJ
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJK
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKL
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLM
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMN
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNO
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOP
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOPQ
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOPQR
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOPQRS
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOPQRST
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOPQRSTU
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOPQRSTUV
# Key = 3
# ------------
#
# PKL OAYNAP!
#
# Pdeo iaoowca swo ajynulpaz qoejc gau = jejapaaj.
#
# wxyzabcdefghijklmnopqrstuv
#
# WXYZABCDEFGHIJKLMNOPQRSTUV
#
#
#
#
# Q
#
# QL
#
# QLM
#
# QLM P
#
# QLM PB
#
# QLM PBZ
#
# QLM PBZO
#
# QLM PBZOB
#
# QLM PBZOBQ
#
# QLM PBZOBQ!
#
# QLM PBZOBQ!
#
#
# QLM PBZOBQ!
#
#
#
# QLM PBZOBQ!
#
# Q
#
# QLM PBZOBQ!
#
# Qe
#
# QLM PBZOBQ!
#
# Qef
#
# QLM PBZOBQ!
#
# Qefp
#
# QLM PBZOBQ!
#
# Qefp j
#
# QLM PBZOBQ!
#
# Qefp jb
#
# QLM PBZOBQ!
#
# Qefp jbp
#
# QLM PBZOBQ!
#
# Qefp jbpp
#
# QLM PBZOBQ!
#
# Qefp jbppx
#
# QLM PBZOBQ!
#
# Qefp jbppxd
#
# QLM PBZOBQ!
#
# Qefp jbppxdb
#
# QLM PBZOBQ!
#
# Qefp jbppxdb t
#
# QLM PBZOBQ!
#
# Qefp jbppxdb tx
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp b
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bk
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkz
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzo
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzov
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovm
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmq
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqb
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba r
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rp
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpf
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfk
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd h
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hb
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv =
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = k
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kf
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfk
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkb
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbq
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqb
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbb
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
#
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# x
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xy
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyz
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyza
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzab
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabc
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcd
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcde
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdef
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefg
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefgh
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghi
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghij
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijk
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijkl
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklm
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmn
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmno
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnop
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopq
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqr
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrs
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrst
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstu
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuv
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
#
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# X
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XY
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZ
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZA
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZAB
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABC
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCD
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDE
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEF
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFG
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGH
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHI
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJ
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJK
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKL
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLM
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMN
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNO
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOP
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQ
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQR
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQRS
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQRST
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQRSTU
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQRSTUV
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQRSTUVW
# Key = 4
# ------------
#
# QLM PBZOBQ!
#
# Qefp jbppxdb txp bkzovmqba rpfkd hbv = kfkbqbbk.
#
# xyzabcdefghijklmnopqrstuvw
#
# XYZABCDEFGHIJKLMNOPQRSTUVW
#
#
#
#
# R
#
# RM
#
# RMN
#
# RMN Q
#
# RMN QC
#
# RMN QCA
#
# RMN QCAP
#
# RMN QCAPC
#
# RMN QCAPCR
#
# RMN QCAPCR!
#
# RMN QCAPCR!
#
#
# RMN QCAPCR!
#
#
#
# RMN QCAPCR!
#
# R
#
# RMN QCAPCR!
#
# Rf
#
# RMN QCAPCR!
#
# Rfg
#
# RMN QCAPCR!
#
# Rfgq
#
# RMN QCAPCR!
#
# Rfgq k
#
# RMN QCAPCR!
#
# Rfgq kc
#
# RMN QCAPCR!
#
# Rfgq kcq
#
# RMN QCAPCR!
#
# Rfgq kcqq
#
# RMN QCAPCR!
#
# Rfgq kcqqy
#
# RMN QCAPCR!
#
# Rfgq kcqqye
#
# RMN QCAPCR!
#
# Rfgq kcqqyec
#
# RMN QCAPCR!
#
# Rfgq kcqqyec u
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uy
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq c
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq cl
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq cla
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clap
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapw
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwn
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnr
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrc
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb s
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sq
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqg
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgl
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle i
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle ic
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw =
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = l
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lg
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lgl
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglc
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcr
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrc
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrcc
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
#
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# y
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yz
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yza
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzab
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabc
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcd
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcde
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdef
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefg
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefgh
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghi
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghij
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijk
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijkl
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklm
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmn
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmno
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnop
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopq
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqr
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrs
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrst
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstu
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuv
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvw
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
#
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# Y
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZ
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZA
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZAB
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABC
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCD
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDE
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEF
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFG
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGH
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHI
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJ
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJK
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKL
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLM
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMN
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNO
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOP
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQ
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQR
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQRS
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQRST
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQRSTU
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQRSTUV
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQRSTUVW
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQRSTUVWX
# Key = 5
# ------------
#
# RMN QCAPCR!
#
# Rfgq kcqqyec uyq clapwnrcb sqgle icw = lglcrccl.
#
# yzabcdefghijklmnopqrstuvwx
#
# YZABCDEFGHIJKLMNOPQRSTUVWX
#
#
#
#
# S
#
# SN
#
# SNO
#
# SNO R
#
# SNO RD
#
# SNO RDB
#
# SNO RDBQ
#
# SNO RDBQD
#
# SNO RDBQDS
#
# SNO RDBQDS!
#
# SNO RDBQDS!
#
#
# SNO RDBQDS!
#
#
#
# SNO RDBQDS!
#
# S
#
# SNO RDBQDS!
#
# Sg
#
# SNO RDBQDS!
#
# Sgh
#
# SNO RDBQDS!
#
# Sghr
#
# SNO RDBQDS!
#
# Sghr l
#
# SNO RDBQDS!
#
# Sghr ld
#
# SNO RDBQDS!
#
# Sghr ldr
#
# SNO RDBQDS!
#
# Sghr ldrr
#
# SNO RDBQDS!
#
# Sghr ldrrz
#
# SNO RDBQDS!
#
# Sghr ldrrzf
#
# SNO RDBQDS!
#
# Sghr ldrrzfd
#
# SNO RDBQDS!
#
# Sghr ldrrzfd v
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vz
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr d
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dm
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmb
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbq
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqx
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxo
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxos
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosd
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc t
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc tr
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trh
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhm
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf j
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jd
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx =
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = m
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mh
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhm
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmd
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmds
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsd
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsdd
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
#
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# z
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# za
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zab
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabc
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcd
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcde
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdef
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefg
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefgh
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghi
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghij
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijk
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijkl
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklm
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmn
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmno
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnop
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopq
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqr
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrs
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrst
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstu
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuv
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvw
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwx
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
#
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# Z
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZA
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZAB
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABC
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCD
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDE
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEF
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFG
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGH
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHI
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJ
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJK
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKL
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLM
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMN
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNO
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOP
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQ
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQR
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRS
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRST
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRSTU
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRSTUV
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRSTUVW
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRSTUVWX
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRSTUVWXY
# Key = 6
# ------------
#
# SNO RDBQDS!
#
# Sghr ldrrzfd vzr dmbqxosdc trhmf jdx = mhmdsddm.
#
# zabcdefghijklmnopqrstuvwxy
#
# ZABCDEFGHIJKLMNOPQRSTUVWXY
#
#
#
#
# T
#
# TO
#
# TOP
#
# TOP S
#
# TOP SE
#
# TOP SEC
#
# TOP SECR
#
# TOP SECRE
#
# TOP SECRET
#
# TOP SECRET!
#
# TOP SECRET!
#
#
# TOP SECRET!
#
#
#
# TOP SECRET!
#
# T
#
# TOP SECRET!
#
# Th
#
# TOP SECRET!
#
# Thi
#
# TOP SECRET!
#
# This
#
# TOP SECRET!
#
# This m
#
# TOP SECRET!
#
# This me
#
# TOP SECRET!
#
# This mes
#
# TOP SECRET!
#
# This mess
#
# TOP SECRET!
#
# This messa
#
# TOP SECRET!
#
# This messag
#
# TOP SECRET!
#
# This message
#
# TOP SECRET!
#
# This message w
#
# TOP SECRET!
#
# This message wa
#
# TOP SECRET!
#
# This message was
#
# TOP SECRET!
#
# This message was e
#
# TOP SECRET!
#
# This message was en
#
# TOP SECRET!
#
# This message was enc
#
# TOP SECRET!
#
# This message was encr
#
# TOP SECRET!
#
# This message was encry
#
# TOP SECRET!
#
# This message was encryp
#
# TOP SECRET!
#
# This message was encrypt
#
# TOP SECRET!
#
# This message was encrypte
#
# TOP SECRET!
#
# This message was encrypted
#
# TOP SECRET!
#
# This message was encrypted u
#
# TOP SECRET!
#
# This message was encrypted us
#
# TOP SECRET!
#
# This message was encrypted usi
#
# TOP SECRET!
#
# This message was encrypted usin
#
# TOP SECRET!
#
# This message was encrypted using
#
# TOP SECRET!
#
# This message was encrypted using k
#
# TOP SECRET!
#
# This message was encrypted using ke
#
# TOP SECRET!
#
# This message was encrypted using key
#
# TOP SECRET!
#
# This message was encrypted using key =
#
# TOP SECRET!
#
# This message was encrypted using key = n
#
# TOP SECRET!
#
# This message was encrypted using key = ni
#
# TOP SECRET!
#
# This message was encrypted using key = nin
#
# TOP SECRET!
#
# This message was encrypted using key = nine
#
# TOP SECRET!
#
# This message was encrypted using key = ninet
#
# TOP SECRET!
#
# This message was encrypted using key = ninete
#
# TOP SECRET!
#
# This message was encrypted using key = ninetee
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
#
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# a
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# ab
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abc
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcd
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcde
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdef
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefg
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefgh
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghi
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghij
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijk
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijkl
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklm
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmn
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmno
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnop
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopq
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqr
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrs
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrst
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstu
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuv
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvw
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwx
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxy
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
#
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# A
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# AB
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABC
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCD
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDE
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEF
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFG
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGH
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHI
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJ
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJK
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJKL
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJKLM
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJKLMN
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJKLMNO
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJKLMNOP
#
# TOP SECRET!
#
# This message was encrypted using key = nineteen.
#
# abcdefghijklmnopqrstuvwxyz
#
# ABCDEFGHIJKLMNOPQ
#
# TOP SECRET!
#
# ...
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZ
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZA
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZAB
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABC
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCD
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDE
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEF
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFG
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGH
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHI
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJ
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJK
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJKL
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJKLM
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJKLMN
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJKLMNO
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJKLMNOP
# Key = 23
# ------------
#
# JEF IUSHUJ!
#
# Jxyi cuiiqwu mqi udshofjut kiydw auo = dydujuud.
#
# qrstuvwxyzabcdefghijklmnop
#
# QRSTUVWXYZABCDEFGHIJKLMNOP
#
#
#
#
# K
#
# KF
#
# KFG
#
# KFG J
#
# KFG JV
#
# KFG JVT
#
# KFG JVTI
#
# KFG JVTIV
#
# KFG JVTIVK
#
# KFG JVTIVK!
#
# KFG JVTIVK!
#
#
# KFG JVTIVK!
#
#
#
# KFG JVTIVK!
#
# K
#
# KFG JVTIVK!
#
# Ky
#
# KFG JVTIVK!
#
# Kyz
#
# KFG JVTIVK!
#
# Kyzj
#
# KFG JVTIVK!
#
# Kyzj d
#
# KFG JVTIVK!
#
# Kyzj dv
#
# KFG JVTIVK!
#
# Kyzj dvj
#
# KFG JVTIVK!
#
# Kyzj dvjj
#
# KFG JVTIVK!
#
# Kyzj dvjjr
#
# KFG JVTIVK!
#
# Kyzj dvjjrx
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv n
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nr
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj v
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj ve
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vet
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj veti
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetip
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipg
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgk
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkv
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu l
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu lj
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljz
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljze
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex b
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bv
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp =
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = e
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ez
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = eze
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezev
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevk
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkv
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvv
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
#
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# r
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rs
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rst
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstu
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuv
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvw
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwx
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxy
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyz
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyza
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzab
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabc
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcd
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcde
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdef
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefg
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefgh
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghi
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghij
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijk
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijkl
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklm
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmn
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmno
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnop
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
#
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# R
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RS
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RST
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTU
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUV
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVW
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWX
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXY
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZ
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZA
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZAB
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABC
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCD
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDE
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEF
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFG
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGH
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHI
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJ
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJK
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJKL
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJKLM
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJKLMN
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJKLMNO
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJKLMNOP
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJKLMNOPQ
# Key = 24
# ------------
#
# KFG JVTIVK!
#
# Kyzj dvjjrxv nrj vetipgkvu ljzex bvp = ezevkvve.
#
# rstuvwxyzabcdefghijklmnopq
#
# RSTUVWXYZABCDEFGHIJKLMNOPQ
#
#
#
#
# L
#
# LG
#
# LGH
#
# LGH K
#
# LGH KW
#
# LGH KWU
#
# LGH KWUJ
#
# LGH KWUJW
#
# LGH KWUJWL
#
# LGH KWUJWL!
#
# LGH KWUJWL!
#
#
# LGH KWUJWL!
#
#
#
# LGH KWUJWL!
#
# L
#
# LGH KWUJWL!
#
# Lz
#
# LGH KWUJWL!
#
# Lza
#
# LGH KWUJWL!
#
# Lzak
#
# LGH KWUJWL!
#
# Lzak e
#
# LGH KWUJWL!
#
# Lzak ew
#
# LGH KWUJWL!
#
# Lzak ewk
#
# LGH KWUJWL!
#
# Lzak ewkk
#
# LGH KWUJWL!
#
# Lzak ewkks
#
# LGH KWUJWL!
#
# Lzak ewkksy
#
# LGH KWUJWL!
#
# Lzak ewkksyw
#
# LGH KWUJWL!
#
# Lzak ewkksyw o
#
# LGH KWUJWL!
#
# Lzak ewkksyw os
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk w
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wf
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfu
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfuj
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujq
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqh
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhl
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlw
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv m
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mk
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mka
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkaf
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy c
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cw
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq =
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = f
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fa
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = faf
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafw
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwl
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlw
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlww
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
#
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# s
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# st
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stu
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuv
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvw
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwx
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxy
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyz
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyza
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzab
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabc
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcd
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcde
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdef
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefg
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefgh
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghi
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghij
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijk
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijkl
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklm
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmn
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmno
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnop
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopq
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
#
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# S
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# ST
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STU
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUV
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVW
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWX
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXY
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZ
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZA
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZAB
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABC
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCD
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDE
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEF
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFG
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGH
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHI
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJ
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJK
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKL
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKLM
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKLMN
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKLMNO
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKLMNOP
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKLMNOPQ
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKLMNOPQR
# Key = 25
# ------------
#
# LGH KWUJWL!
#
# Lzak ewkksyw osk wfujqhlwv mkafy cwq = fafwlwwf.
#
# stuvwxyzabcdefghijklmnopqr
#
# STUVWXYZABCDEFGHIJKLMNOPQR
